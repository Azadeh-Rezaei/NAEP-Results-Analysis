# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %%
# import data
path = r'/Users/azadehrezaei/Desktop/NAEP Results Analysis'
df = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'states_all_extended.csv'), index_col = False)

# %%
df.head()
# Out:
#        PRIMARY_KEY       STATE  YEAR  ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  \
# 0     1992_ALABAMA     ALABAMA  1992     NaN      2678885.0         304177.0
# 1      1992_ALASKA      ALASKA  1992     NaN      1049591.0         106780.0
# 2     1992_ARIZONA     ARIZONA  1992     NaN      3258079.0         297888.0
# 3    1992_ARKANSAS    ARKANSAS  1992     NaN      1711959.0         178571.0
# 4  1992_CALIFORNIA  CALIFORNIA  1992     NaN     26260025.0        2072470.0
#
#    STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  INSTRUCTION_EXPENDITURE  \
# 0      1659028.0       715680.0          2653798.0                1481703.0
# 1       720711.0       222100.0           972488.0                 498362.0
# 2      1369815.0      1590376.0          3401580.0                1435908.0
# 3       958785.0       574603.0          1743022.0                 964323.0
# 4     16546514.0      7641041.0         27138832.0               14358922.0
#
# ...

# %%
# the dimensions of my target dataset
df.shape
# Out:
# (1715, 266)

# %%
# columns and data types
df.dtypes
# Out:
# PRIMARY_KEY              object
# STATE                    object
# YEAR                      int64
# ENROLL                  float64
# TOTAL_REVENUE           float64
#                          ...
# G08_AM_A_MATHEMATICS    float64
# G08_HP_A_READING        float64
# G08_HP_A_MATHEMATICS    float64
# G08_TR_A_READING        float64
# G08_TR_A_MATHEMATICS    float64
# Length: 266, dtype: object

# %%
# columns/titles
df.columns
# Out:
# Index(['PRIMARY_KEY', 'STATE', 'YEAR', 'ENROLL', 'TOTAL_REVENUE',
#        'FEDERAL_REVENUE', 'STATE_REVENUE', 'LOCAL_REVENUE',
#        'TOTAL_EXPENDITURE', 'INSTRUCTION_EXPENDITURE',
#        ...
#        'G08_HI_A_READING', 'G08_HI_A_MATHEMATICS', 'G08_AS_A_READING',
#        'G08_AS_A_MATHEMATICS', 'G08_AM_A_READING', 'G08_AM_A_MATHEMATICS',
#        'G08_HP_A_READING', 'G08_HP_A_MATHEMATICS', 'G08_TR_A_READING',
#        'G08_TR_A_MATHEMATICS'],
#       dtype='object', length=266)

# %%
# selecting certain columns from the dataset
var_list = ["PRIMARY_KEY", "STATE","YEAR","ENROLL","TOTAL_REVENUE","FEDERAL_REVENUE","STATE_REVENUE", "LOCAL_REVENUE","TOTAL_EXPENDITURE","INSTRUCTION_EXPENDITURE","SUPPORT_SERVICES_EXPENDITURE","OTHER_EXPENDITURE","CAPITAL_OUTLAY_EXPENDITURE","A_A_A","G01_A_A","G02_A_A","G03_A_A","G04_A_A","G05_A_A","G06_A_A","G07_A_A","G08_A_A","G09_A_A","G10_A_A","G11_A_A","G12_A_A","KG_A_A","PK_A_A","G04_A_A_READING","G04_A_A_MATHEMATICS","G04_A_M_READING","G04_A_M_MATHEMATICS","G04_A_F_READING","G04_A_F_MATHEMATICS","G04_WH_A_READING","G04_WH_A_MATHEMATICS","G04_BL_A_READING","G04_BL_A_MATHEMATICS","G04_HI_A_READING","G04_HI_A_MATHEMATICS","G04_AS_A_READING","G04_AS_A_MATHEMATICS","G04_AM_A_READING","G04_AM_A_MATHEMATICS","G04_HP_A_READING","G04_HP_A_MATHEMATICS","G04_TR_A_READING","G04_TR_A_MATHEMATICS","G08_A_A_READING","G08_A_A_MATHEMATICS","G08_A_M_READING","G08_A_M_MATHEMATICS","G08_A_F_READING","G08_A_F_MATHEMATICS","G08_WH_A_READING","G08_WH_A_MATHEMATICS","G08_BL_A_READING","G08_BL_A_MATHEMATICS","G08_HI_A_READING","G08_HI_A_MATHEMATICS","G08_AS_A_READING","G08_AS_A_MATHEMATICS","G08_AM_A_READING","G08_AM_A_MATHEMATICS","G08_HP_A_READING","G08_HP_A_MATHEMATICS","G08_TR_A_READING","G08_TR_A_MATHEMATICS"]

# %%
# create a subset of the dataframe df
df_clean = df[var_list]

# %%
df_clean.shape
# Out:
# (1715, 68)

# %%
df_clean.dtypes
# Out:
# PRIMARY_KEY              object
# STATE                    object
# YEAR                      int64
# ENROLL                  float64
# TOTAL_REVENUE           float64
#                          ...
# G08_AM_A_MATHEMATICS    float64
# G08_HP_A_READING        float64
# G08_HP_A_MATHEMATICS    float64
# G08_TR_A_READING        float64
# G08_TR_A_MATHEMATICS    float64
# Length: 68, dtype: object

# %%
# Set to show all the columns
pd.set_option('display.max_rows', None)

# %%
# Finding the number of missing values
df_clean.isnull().sum()
# Out:
# PRIMARY_KEY                        0
# STATE                              0
# YEAR                               0
# ENROLL                           491
# TOTAL_REVENUE                    440
# FEDERAL_REVENUE                  440
# STATE_REVENUE                    440
# LOCAL_REVENUE                    440
# TOTAL_EXPENDITURE                440
# INSTRUCTION_EXPENDITURE          440
# SUPPORT_SERVICES_EXPENDITURE     440
# OTHER_EXPENDITURE                491
# CAPITAL_OUTLAY_EXPENDITURE       440
# A_A_A                             83
# G01_A_A                           83
# G02_A_A                           83
# G03_A_A                           83
# G04_A_A                           83
# G05_A_A                           83
# G06_A_A                           83
# G07_A_A                           83
# G08_A_A                           83
# G09_A_A                           83
# G10_A_A                           83
# G11_A_A                           83
# ...

# %%
# Only keeping the data for the years when the NAEP was administered in grades 4 and 8 for BOTH Mathematics & Reading
df_clean = df_clean[df_clean['YEAR'].isin([2003, 2005, 2007, 2009, 2011, 2013, 2015, 2017, 2019])]

# %%
# Resetting the index:
df_clean = df_clean.reset_index()

# %%
# Deleting the old index columns:
del df_clean['index']

# %%
df_clean.head()
# Out:
#        PRIMARY_KEY       STATE  YEAR     ENROLL  TOTAL_REVENUE  \
# 0     2003_ALABAMA     ALABAMA  2003   727900.0      5196054.0
# 1      2003_ALASKA      ALASKA  2003   133303.0      1425948.0
# 2     2003_ARIZONA     ARIZONA  2003   875111.0      6529894.0
# 3    2003_ARKANSAS    ARKANSAS  2003   450158.0      3241275.0
# 4  2003_CALIFORNIA  CALIFORNIA  2003  6226552.0     59815855.0
#
#    FEDERAL_REVENUE  STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# 0         567704.0      2966981.0      1661369.0          5298932.0
# 1         259423.0       813371.0       353154.0          1610289.0
# 2         740579.0      2912629.0      2876686.0          6210287.0
# 3         379947.0      2394336.0       466992.0          3242799.0
# 4        5795655.0     33617766.0     20402434.0         59749885.0
#
#    INSTRUCTION_EXPENDITURE  ...  G08_HI_A_READING  G08_HI_A_MATHEMATICS  \
# 0                2817111.0  ...               NaN                   NaN
# ...

# %%
df_clean.shape
# Out:
# (477, 68)

# %%
# Finding Duplicates:
df_dups = df_clean[df_clean.duplicated()]

# %%
# No full duplicates in the set:
df_dups
# Out:
# Empty DataFrame
# ...

# %%
# Basic descriptive statistical analysis:
df_clean.describe().T
# Out:
#                               count          mean           std       min  \
# YEAR                          477.0  2.011000e+03  5.169399e+00    2003.0
# ENROLL                        357.0  9.451255e+05  1.115594e+06   44179.0
# TOTAL_REVENUE                 357.0  1.115479e+07  1.361662e+07  801008.0
# FEDERAL_REVENUE               357.0  1.022119e+06  1.388952e+06   75856.0
# STATE_REVENUE                 357.0  5.121749e+06  6.367098e+06       0.0
# LOCAL_REVENUE                 357.0  5.010925e+06  6.368771e+06   35182.0
# TOTAL_EXPENDITURE             357.0  1.126676e+07  1.388169e+07  805362.0
# INSTRUCTION_EXPENDITURE       357.0  5.824046e+06  7.293471e+06  330698.0
# SUPPORT_SERVICES_EXPENDITURE  357.0  3.301162e+06  3.869866e+06  239435.0
# OTHER_EXPENDITURE             357.0  5.025831e+05  6.018313e+05   27608.0
# CAPITAL_OUTLAY_EXPENDITURE    357.0  1.087787e+06  1.549918e+06   20070.0
# A_A_A                         408.0  9.727545e+05  1.146026e+06   69433.0
# ...

# %%
# Exporting the clean dataset:
df_clean.to_csv(os.path.join(path,'02 Data', 'Prepared Data', 'states_all_extended_clean.csv'))
